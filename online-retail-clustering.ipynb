# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/prajna/Documents/Cluster Analysis/data/online_retail_II.xlsx",sheet_name=0)

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
df.describe(include='O')
# Out:
#         Invoice StockCode                         Description         Country
# count    525461    525461                              522533          525461
# unique    28816      4632                                4681              40
# top      537434    85123A  WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# freq        675      3516                                3549          485852

# %%
df[df["Customer ID"].isna()].head(20)
# Out:
#      Invoice StockCode                       Description  Quantity  \
# 263   489464     21733                      85123a mixed       -96
# 283   489463     71477                             short      -240
# 284   489467    85123A                       21733 mixed      -192
# 470   489521     21646                               NaN       -50
# 577   489525    85226C         BLUE PULL BACK RACING CAR         1
# 578   489525     85227       SET/6 3D KIT CARDS FOR KIDS         1
# 1055  489548     22271              FELTCRAFT DOLL ROSIE         1
# 1056  489548     22254              FELT TOADSTOOL LARGE        12
# 1057  489548     22273              FELTCRAFT DOLL MOLLY         3
# 1058  489548     22195      LARGE HEART MEASURING SPOONS         1
# 1059  489548     22131  FOOD CONTAINER SET 3 LOVE HEART          2
# 1060  489548     22079        RIBBON REEL HEARTS DESIGN         10
# 1061  489548     22138     BAKING SET 9 PIECE RETROSPOT          3
# ...

# %%
df[df['Quantity']<0].head()
# Out:
#      Invoice StockCode                    Description  Quantity  \
# 178  C489449     22087       PAPER BUNTING WHITE LACE       -12
# 179  C489449    85206A   CREAM FELT EASTER EGG BASKET        -6
# 180  C489449     21895  POTTING SHED SOW 'N' GROW SET        -4
# 181  C489449     21896             POTTING SHED TWINE        -6
# 182  C489449     22083     PAPER CHAIN KIT RETRO SPOT       -12
#
#             InvoiceDate  Price  Customer ID    Country
# 178 2009-12-01 10:33:00   2.95      16321.0  Australia
# 179 2009-12-01 10:33:00   1.65      16321.0  Australia
# 180 2009-12-01 10:33:00   4.25      16321.0  Australia
# 181 2009-12-01 10:33:00   2.10      16321.0  Australia
# 182 2009-12-01 10:33:00   2.95      16321.0  Australia

# %% [markdown]
# typecast Invoice to string. then, check how many of them does not match the type of 6 digits.

# %%
df['Invoice']=df['Invoice'].astype('str')
df[df['Invoice'].str.match("^\\d{6}$")==False]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 524695  C538123     22956          36 FOIL HEART CAKE CASES        -2
# 524696  C538124         M                            Manual        -4
# 524697  C538124     22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 524698  C538124     22423          REGENCY CAKESTAND 3 TIER        -1
# 525282  C538164    35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...

# %% [markdown]
# let's scrub out all the numbers from each invoice and trhen check the uniques, in the data source, C was mentioned, the presence of C indicates cancelled invoices

# %%
df['Invoice'].str.replace("[0-9]","",regex=True).unique()
# Out:
# array(['', 'C', 'A'], dtype=object)

# %% [markdown]
# C is fine because it means cancelled invoices, however there are some A as well. we need to check that.

# %%
df[df["Invoice"].str.startswith("A")]
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
#
#            Price  Customer ID         Country
# 179403 -53594.36          NaN  United Kingdom
# 276274 -44031.79          NaN  United Kingdom
# 403472 -38925.87          NaN  United Kingdom

# %% [markdown]
# lets clean these, because price is -ve and also customer IDs are null.
# StockCode: item code. A 5-digit number uniquely assigned to each distinct product. let's check StockCode for all now

# %%
df['StockCode'] = df['StockCode'].astype('str')
df[df["StockCode"].str.match("^\\d{5}$")==False]
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 12      489436    48173C                DOOR MAT BLACK FLOCK         10
# 23      489436    35004B          SET OF 3 BLACK FLYING DUCKS        12
# 28      489436    84596F         SMALL MARSHMALLOWS PINK BOWL         8
# ...        ...       ...                                  ...       ...
# 525387  538170    84029E       RED WOOLLY HOTTIE WHITE HEART.         2
# 525388  538170    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         2
# 525389  538170    85232B      SET OF 3 BABUSHKA STACKING TINS         2
# 525435  538171    47591D      PINK FAIRY CAKE CHILDRENS APRON         1
# 525436  538171    47591B             SCOTTIES CHILDRENS APRON         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# well, there are >80k records where stockcodes are not as per document.
#
# But, they seem to be legit transactions, because customer Id are there,
#
# to bve more comprehensive, let's check if there are any other patterns present except for the pattern 5 digits followed by a letter

# %%
df[(df["StockCode"].str.match("^\\d{5}$")==False) & (df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$")==False)]
# Out:
#         Invoice StockCode     Description  Quantity         InvoiceDate  \
# 89       489439      POST         POSTAGE         3 2009-12-01 09:28:00
# 126      489444      POST         POSTAGE         1 2009-12-01 09:55:00
# 173      489447      POST         POSTAGE         1 2009-12-01 10:10:00
# 625      489526      POST         POSTAGE         6 2009-12-01 11:50:00
# 735     C489535         D        Discount        -1 2009-12-01 12:11:00
# ...         ...       ...             ...       ...                 ...
# 524776   538147         M          Manual         1 2010-12-09 16:11:00
# 524887   538148       DOT  DOTCOM POSTAGE         1 2010-12-09 16:26:00
# 525000   538149       DOT  DOTCOM POSTAGE         1 2010-12-09 16:27:00
# 525126   538153       DOT  DOTCOM POSTAGE         1 2010-12-09 16:31:00
# 525147   538154       DOT  DOTCOM POSTAGE         1 2010-12-09 16:35:00
#
#          Price  Customer ID         Country
# 89       18.00      12682.0          France
# ...

# %% [markdown]
# so, we do get some funky looking stockcodes which do not follow patterns. and uniquely some of them do not have any Customer ID, one has -1 quantity as well.
#
# let's check the unique stockcodes just to see the extent to which the stockcodes do not follow the expected pattern

# %%
df[(df["StockCode"].str.match("^\\d{5}$")==False) & (df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$")==False)]['StockCode'].unique()
# Out:
# array(['POST', 'D', 'DCGS0058', 'DCGS0068', 'DOT', 'M', 'DCGS0004',
#        'DCGS0076', 'C2', 'BANK CHARGES', 'DCGS0003', 'TEST001',
#        'gift_0001_80', 'DCGS0072', 'gift_0001_20', 'DCGS0044', 'TEST002',
#        'gift_0001_10', 'gift_0001_50', 'DCGS0066N', 'gift_0001_30',
#        'PADS', 'ADJUST', 'gift_0001_40', 'gift_0001_60', 'gift_0001_70',
#        'gift_0001_90', 'DCGSSGIRL', 'DCGS0006', 'DCGS0016', 'DCGS0027',
#        'DCGS0036', 'DCGS0039', 'DCGS0060', 'DCGS0056', 'DCGS0059', 'GIFT',
#        'DCGSLBOY', 'm', 'DCGS0053', 'DCGS0062', 'DCGS0037', 'DCGSSBOY',
#        'DCGSLGIRL', 'S', 'DCGS0069', 'DCGS0070', 'DCGS0075', 'B',
#        'DCGS0041', 'ADJUST2', '47503J ', 'C3', 'SP1002', 'AMAZONFEE'],
#       dtype=object)

# %% [markdown]
# there's a lot!
#
# to deal with it, we'll have to go through each of these to understand what each of these mean.

# %%
df[df["StockCode"].str.contains("^DOT")]
# Out:
#        Invoice StockCode     Description  Quantity         InvoiceDate  \
# 2379    489597       DOT  DOTCOM POSTAGE         1 2009-12-01 14:28:00
# 2539    489600       DOT  DOTCOM POSTAGE         1 2009-12-01 14:43:00
# 2551    489601       DOT  DOTCOM POSTAGE         1 2009-12-01 14:44:00
# 2571    489602       DOT  DOTCOM POSTAGE         1 2009-12-01 14:45:00
# 2619    489603       DOT  DOTCOM POSTAGE         1 2009-12-01 14:46:00
# ...        ...       ...             ...       ...                 ...
# 524272  538071       DOT  DOTCOM POSTAGE         1 2010-12-09 14:09:00
# 524887  538148       DOT  DOTCOM POSTAGE         1 2010-12-09 16:26:00
# 525000  538149       DOT  DOTCOM POSTAGE         1 2010-12-09 16:27:00
# 525126  538153       DOT  DOTCOM POSTAGE         1 2010-12-09 16:31:00
# 525147  538154       DOT  DOTCOM POSTAGE         1 2010-12-09 16:35:00
#
#          Price  Customer ID         Country
# 2379    647.19          NaN  United Kingdom
# ...

# %% [markdown]
# ![0A22EC28-1A01-473F-A162-E2431F34868A.jpeg](attachment:0A22EC28-1A01-473F-A162-E2431F34868A.jpeg)
#
# ![AD2FB156-5E93-4F25-AACB-BF1B53334382.jpeg](attachment:AD2FB156-5E93-4F25-AACB-BF1B53334382.jpeg)
#
# so, the only code that we're going to keep is PADS for clustering

# %% [markdown]
# we could look at Description and country, but that EDA is not needed for clustering.

# %% [markdown]
# # Cleaning based on the insights we got so far

# %%
cleaned_df = df.copy()

# %%
cleaned_df["Invoice"] = cleaned_df["Invoice"].astype('str')
# remove the cancelled and accounts invoices
mask = (
    cleaned_df["Invoice"].str.match("^\\d{6}$") == True
)
cleaned_df = cleaned_df[mask]
cleaned_df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
cleaned_df["StockCode"] = cleaned_df["StockCode"].astype('str')
# remove the redundant StockCodes
mask = (
    cleaned_df["StockCode"].str.match("^\\d{5}$") == True
    | cleaned_df["StockCode"].str.match("^\\d{5}a-zA-z+$") == True
    | cleaned_df["StockCode"].str.match("^PADS$") == True
)
cleaned_df = cleaned_df[mask]
cleaned_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hx/_mhnx0096mz4t1j62rs9hkg40000gn/T/ipykernel_18539/1270757691.py in ?()
# ----> 4 cleaned_df["StockCode"] = cleaned_df["StockCode"].astype('str')
#       5 # remove the redundant StockCodes
#       6 mask = (
#       7     cleaned_df["StockCode"].str.match("^\\d{5}$") == True
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
cleaned_df["StockCode"] = cleaned_df["StockCode"].astype('str')
